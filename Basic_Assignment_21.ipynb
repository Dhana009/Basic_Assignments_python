# %% [markdown]
# # Basic_Assignment_21

# %% [markdown]
# ### 1. Add the current date to the text file today.txt as a string.

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 14-12-2022

# %% [markdown]
# ### 2. Read the text file today.txt into the string today_string

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 14-12-2022

# %% [markdown]
# ### 3. Parse the date from today_string.

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2022-12-14 00:00:00

# %% [markdown]
# ### 4. List the files in your current directory

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# 10WaysToEaseStress-1166219231-770x533-1.jpg
# 1670678848831.png
# 1670774493429.png
# 1_qZDsWO2YBNzlvUfiOadUjQ.webp
# abc.zip
# abundance-dollar-8851737.jpg
# advanced-systemcare-setup.exe
# Basic_Assignment_12.ipynb
# Basic_Assignment_13.ipynb
# Basic_Assignment_14.ipynb
# Basic_Assignment_15.ipynb
# Basic_Assignment_16.ipynb
# Basic_Assignment_17.ipynb
# Basic_Assignment_18.ipynb
# Basic_Assignment_19.ipynb
# Basic_Assignment_20.ipynb
# Basic_Assignment_21.ipynb
# Basic_Assignment_Eight.ipynb
# Basic_Assignment_Eleven.ipynb
# Basic_Assignment_five.ipynb
# Basic_Assignment_four.ipynb
# Basic_Assignment_Nine.ipynb
# Basic_Assignment_seven.ipynb
# Basic_Assignment_six.ipynb
# Basic_Assignment_Ten.ipynb
# BlueMagic.webp
# books.csv
# books.db
# BraveBrowserSetup.exe
# cofee powder (1).png
# cofee powder (2).png
# cofee powder (3).png
# cofee powder (4).png
# cofee powder (5).png
# cofee powder (6).png
# cofee powder.png
# cofee.png
# cret.jpg
# deskshare.webm
# desktop.ini
# destination
# Dictionary.ipynb
# Diwakar-Jhurani.jpg
# driver_booster_setup.exe
# GeForce_Experience_v3.25.1.27.exe
# helTH.jpg
# image.jpg
# miraculous-powers.jpg
# pyodide_py.tar
# Python Introduction, Installation and Setup - Full Stack Data Science Bootcamp _ iNeuron.mp4
# rptgtpxd-1396254731.avif
# setupoptanememory.zip
# test.txt
# today.txt
# trial.txt
# tuples.ipynb
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# WhatsApp Image 2022-07-11 at 9.31.42 AM.jpeg
# WhatsApp Image 2022-11-28 at 1.37.05 PM.jpeg
# winrar-x64-611.exe
# words.txt
# _Getintopc.com_Internet_Download_Manager_6.41_Build_2.rar
# .gitignore
# Downloads.iml
# misc.xml
# modules.xml
# workspace.xml
# profiles_settings.xml
# Basic_Assignment_12-checkpoint.ipynb
# Basic_Assignment_13-checkpoint.ipynb
# Basic_Assignment_14-checkpoint.ipynb
# Thermodynamics.pdf
# Tuples 1.pdf
# Tuples 1_2.pdf
# Tuples 1_3.pdf
# Tuples 1_4.pdf
# tuples document final.pdf
# Untitled document.pdf
#  Affirmations Exams for Students.mp3
# Affirmations For Wealth .mp3
# affirmations Powerful 50 Positive.mp3
# creativity affirmations louise hay i can do it.mp3
# I AM SUCCESSFUL .mp3
# i can do it - health affirmations by louise hay.mp3
# job success affirmations louise hay i can do it.mp3
# prosperity affirmations louise hay i can do it.mp3
# stress free affirmations  louise hay i can do it.mp3
# Anaconda3-2022.05-Windows-x86_64.exe
# AtomSetup-x64.exe
# audacity-win-3.1.3-64bit.exe
# BlueStacksInstaller_5.9.0.1061_native_3cf15b444d72d5711afe88610e789433_3.exe
# DriverInstaller_signed.exe
# Git-2.39.0-64-bit.exe
# HandBrake-1.5.1-x86_64-Win_GUI.exe
# HuionTablet_WinDriver_v15.6.2.80.exe
# mysql-installer-community-8.0.31.0.msi
# OfficeSetup.exe
# pycharm-community-2022.3.exe
# python-3.10.5-amd64.exe
# python-3.10.5-amd64_2.exe
# rufus-3.20.exe
# Scratch 3.29.1 Setup.exe
# vlc-3.0.17.4-win32.exe
# vs_community__1031686957.1614645894.exe
# windowsdesktop-runtime-6.0.7-win-x64.exe
# ZoomInstallerFull.exe
# console.py
# http.py
# webloop.py
# _core.py
# _package_loader.py
# _state.py
# __init__.py
# docstring.py
# _base.py
# _core_docs.py
# _importhook.py
# __init__.py
# 0e883691dfbf84ce40a5.css
# 247-fd54fbbfb85caf462038.js.download
# 280-a69763e6ca3f265f04e2.js.download
# 517568017.html
# 542521.png
# 566-14bf0073385bf42f6b4d.js.download
# 616-6ce3b4eb4db313f708a0.js.download
# 620-647e1581c043d5e09a48.js.download
# 655-6ca56637fa8c5af27564.js.download
# 72dbcaf226896f6aa2b3.css
# 913-92c22992b2e0af9ebf48.js.download
# 992-93c14b9568003aef6649.js.download
# all.min.css
# anchor.html
# api.js.download
# audio-call-avatar.png
# co-browse.png
# css2
# framework-6f156d06676f80cd912a.js.download
# ga.js.download
# index-3dc9cd41f14d3059d6cb.js.download
# js
# lineicons.css
# main-fc3dc493f834a08eb770.js.download
# new-livechat.js.download
# player.css
# player.js(1).download
# player.js.download
# polyfills-a40ef1678bae11e696dba45124eadd70.js.download
# queue-screen-img.png
# recaptcha__en.js.download
# saved_resource(1).html
# saved_resource(2).html
# saved_resource.html
# short-logo.png
# styles__ltr.css
# vuid.min.js.download
# webpack-3ba22a78c9bb750cc0b0.js.download
# [...slug]-623e5c755507435b0b9b.js.download
# [...slug]-71b74b7ce838a92ca76b.js.download
# [...slug]-b54d62438c5e7c601a27.js.download
# _app-495750753bce54625bf3.js.download
# _buildManifest.js.download
# _ssgManifest.js.download
# mup.xml
# SetupOptaneMemory.exe
# WixLicense.txt
# 4th June live Class Revision and Task Solving.mp4
# Premium Sections - Skill - Lync.mp4
# Premium Sections - Skill - Lync_2.mp4
# python basics 1.mp4
# python basics 2.mp4
# python basics 3.mp4
# python basics 4.mp4
# python basics 5.mp4
# python basics 6 while loop and basic of function.mp4
# 01 Sudhanshu_Course_Overview.mp4
# 02 FSbootcamp.mp4
# 03 FSbootcamp.mp4
# Screenshot_2022-07-19-11-57-21-889_com.app.flutterbecricapp.jpg
# Screenshot_2022-07
# Screenshot_2022-07-20-07-57-00-422_com.thunkable.android.twmrsmy125.CLOCK.jpg
# Screenshot_2022-07-20-08-22-00-449_com.thunkable.android.twmrsmy125.CLOCK.jpg
# Screenshot_2022-07-20-08-47-00-682_com.thunkable.android.twmrsmy125.CLOCK.jpg
# Screenshot_2022-07-20-09-03-44-916_com.thunkable.android.twmrsmy125.CLOCK.jpg
# Screenshot_2022-07-20-09-43-00-757_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-10-00-22-759_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-10-28-02-057_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-10-55-14-831_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-11-24-05-494_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-11-49-54-265_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-12-18-02-247_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-12-46-15-693_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-13-12-39-939_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-13-39-30-440_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-14-08-15-365_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-14-33-27-456_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-15-28-21-093_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-15-55-18-114_com.thunkable.android.twmrsmy125.CLOCK.jpg
# Screenshot_2022-07-20-16-13-53-617_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-16-46-01-121_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-17-18-27-945_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-17-44-24-133_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-18-11-24-016_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-18-38-36-152_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-19-05-24-981_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-19-59-23-065_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-20-24-48-479_com.thunkable.android.twmrsmy125.CLOCK.jpg
# Screenshot_2022-07-20-20-52-54-330_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-21-20-21-915_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-21-48-16-014_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-22-14-39-298_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-22-41-00-265_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-23-08-01-783_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-23-15-57-004_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-23-34-48-316_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-20-23-53-08-133_com.app.flutterbecricapp.jpg
# Screenshot_2022-07-21-00-02-06-959_com.thunkable.android.twmrsmy125.CLOCK.jpg
# Screenshot_2022-07-21-00-27-33-525_com.app.flutterbecricapp.jpg
# Password 123.txt
# idman641build2f.exe
# Readme.txt
# Patch.exe
# Patch.exe

# %% [markdown]
# ### 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os 
os.listdir()
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  '10WaysToEaseStress-1166219231-770x533-1.jpg',
#  '1670678848831.png',
#  '1670774493429.png',
#  '1_qZDsWO2YBNzlvUfiOadUjQ.webp',
#  'abc.zip',
#  'abundance-dollar-8851737.jpg',
#  'advanced-systemcare-setup.exe',
#  'Basic_Assignment_12.ipynb',
#  'Basic_Assignment_13.ipynb',
#  'Basic_Assignment_14.ipynb',
#  'Basic_Assignment_15.ipynb',
#  'Basic_Assignment_16.ipynb',
#  'Basic_Assignment_17.ipynb',
#  'Basic_Assignment_18.ipynb',
#  'Basic_Assignment_19.ipynb',
#  'Basic_Assignment_20.ipynb',
#  'Basic_Assignment_21.ipynb',
#  'Basic_Assignment_Eight.ipynb',
#  'Basic_Assignment_Eleven.ipynb',
#  'Basic_Assignment_five.ipynb',
#  'Basic_Assignment_four.ipynb',
#  'Basic_Assignment_Nine.ipynb',
#  'Basic_Assignment_seven.ipynb',
#  'Basic_Assignment_six.ipynb',
#  'Basic_Assignment_Ten.ipynb',
#  'BlueMagic.webp',
#  'books.csv',
#  'books.db',
#  'BraveBrowserSetup.exe',
#  'cofee powder (1).png',
#  'cofee powder (2).png',
#  'cofee powder (3).png',
#  'cofee powder (4).png',
#  'cofee powder (5).png',
#  'cofee powder (6).png',
#  'cofee powder.png',
#  'cofee.png',
#  'Compressed',
#  'cret.jpg',
#  'deskshare.webm',
#  'desktop.ini',
#  'destination',
#  'Dictionary.ipynb',
#  'Diwakar-Jhurani.jpg',
#  'Documents',
#  'driver_booster_setup.exe',
#  'GeForce_Experience_v3.25.1.27.exe',
#  'helTH.jpg',
#  'image.jpg',
#  'miraculous-powers.jpg',
#  'Music',
#  'Programs',
#  'pyodide_py',
#  'pyodide_py.tar',
#  'Python Introduction, Installation and Setup - Full Stack Data Science Bootcamp _ iNeuron.mp4',
#  'Python Introduction, Installation and Setup - Full Stack Data Science Bootcamp _ iNeuron_files',
#  'rptgtpxd-1396254731.avif',
#  'setupoptanememory',
#  'setupoptanememory.zip',
#  'test.txt',
#  'today.txt',
#  'trial.txt',
#  'tuples.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Video',
#  'WhatsApp Image 2022-07-11 at 9.31.42 AM.jpeg',
#  'WhatsApp Image 2022-11-28 at 1.37.05 PM.jpeg',
#  'winrar-x64-611.exe',
#  'words.txt',
#  '_Getintopc.com_Internet_Download_Manager_6.41_Build_2',
#  '_Getintopc.com_Internet_Download_Manager_6.41_Build_2.rar']

# %% [markdown]
# ### 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

# %% [markdown]
# ### 7. Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('09/04/2000','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 2000-04-09 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# ### 8. What day of the week was your day of birth?

# %%
from datetime import datetime
my_dob = datetime(1997,4,22)
my_dob.strftime("%A")
# Out:
# 'Tuesday'

# %% [markdown]
# ### 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("09/04/2000",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1972, 11, 22, 0, 0)
